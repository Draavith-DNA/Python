# %% [markdown]
# Variable are the fundamental elements used to store the data that can be referenced and manipulated in a program.
#
# In python variable are created when you assign a value to them, and they do not need explicit deceleration to reserve memory space.

# %%
a = 100

# %%
## declaring and assigining the variable

age = 32
height = 6.1
name ="Draavith"
is_student = True

## printing the variables

print("age: ",age)
print("height:", height)
print("name:", name)
print("is the", name,"studest :", is_student)
# Out:
# age:  32
# height: 6.1
# name: Draavith
# is the Draavith studest : True

# %%
## Naming convenstion
## variable name that we decide should be discreptive
## They must start with the letters or underscore and can overall contain letters, numbers and underscore
## Variables name case sensitive


# valid variavle names:
first_name = "Draavith"
age = 20

# Invalid variable name
'''2_age = 10
    first-name = Draavith
    @gamil = draavithn@gmail.com'''

# case sensetive

name = "first vatiable name"
Nmae = "second variable Name"

# %%
## understanding the variables types
## python is dynamically types, type of a variable is determined at runtime

age = 20
height = 5.8 # float
name = "draavith" # str
is_student = True

print(type(name))
# Out:
# <class 'str'>

# %%
## Type conversion
## Type conversion is logical. that is, the string "Draavith" cant be int type but it but the in type can be string cype
age = 25
print(type(age))

age_str = str(age)
print(age_str)
print(type(age_str))
# Out:
# <class 'int'>
# 25
# <class 'str'>

# %%
## Dynamic Typing
## python allows the type of variable to chnage as the program executes
var = 10 #int
print(var, type(var))

var = "Hello" #str
print(var,type(var))

var = 4.32 #float
print(var,type(var))
# Out:
# 10 <class 'int'>
# Hello <class 'str'>
# 4.32 <class 'float'>

# %%
## input

age = input("what is the age")
print(age, type(age))

age_int = int(input("what is the second age"))
print(age, type(age_int))
# Out:
# 4353 <class 'str'>
# 4353 <class 'int'>

# %%
### simple calculator ###
num1 = float(input("enter the first number"))
num2 = float(input("enter the second number"))

sum = num1+num2
difference = num1 - num2
product = num1 * num2
quotient = num1 / num2
reminder = num1 %num2

print("sum= ",sum)
print("difference= ",difference)
print("product= ",product)
print("quotient= ",quotient)
print("remainder= ",reminder)
# Out:
# sum=  10.0
# difference=  0.0
# product=  25.0
# quotient=  1.0
# remainder=  0.0
