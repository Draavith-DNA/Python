# %% [markdown]
# DataTypes
#
# defination: datatypes are the classification of data which tells the compiler or interpreter how the programmer intendes to use data
#
# They determine the types of operations that can be performed on the data, the values that the data can take, and the amount of memory needed to store the data

# %%
## Integers example
age=35
type(age)
# Out:
# int

# %%
## floating point data_type
height = 5.8
print(height)
type(height)
# Out:
# 5.8
# float

# %%
## string datatype example
name ="draavith"
type(name)
# Out:
# str

# %%
## boolean data_type example
a= 10
b= 10
type(a==b)
# Out:
# bool

# %%
## common errors
## can not concatinate string and integer
''' result = "hello" + 5 '''

result= "hello" + "5"
print(result)
# Out:
# hello5
