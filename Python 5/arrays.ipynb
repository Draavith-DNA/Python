# %% [markdown]
# ## Arraya
# ->An arraty is the collection of the elements stored in the contigous memory location. And they allow for efficient access and manupalition of data
#
# ->All elements of array are of some data type (int, float etc..)
#
# ->In python we use list insted of array as they provide more flexibility. however, python provide ability to use array via libraries such as numpy

# %%
## the array library provides an efficient way to store and manipulate arrays of basic data types. It is more memory-efficient than lists, as it stores elements in a contiguous block of memory. The array module supports various data types, such as integers, floats, and characters.
## here i is the type code for signed integers. The array is created with the values [1, 2, 3, 4, 5] and printed to the console.

import array
arr = array.array('i', [1, 2, 3, 4, 5])
print(arr)
# Out:
# array('i', [1, 2, 3, 4, 5])
