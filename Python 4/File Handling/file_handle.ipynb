# %% [markdown]
# ## File Hnadling:
# this means performing the CRUD operations that we can perform in files

# %%
# must use opean function to opean the file which is used to opean the file
# 'r' -> Read
# 'w' -> Creates or overwrites the file
# 'a' -> Append data to the file
# 'x' -> Creates the file, if the file is already present it will give an error

# %%
p = open(r"E:\CWH Data Science\coders of delehi\first session\data.json")
print(p.read())
# Out:
# {
#     "users": [
#         {"id": 1, "name": "Amit", "friends": [2, 3], "liked_pages": [101]},
#         {"id": 2, "name": "Priya", "friends": [1, 4], "liked_pages": [102]},
#         {"id": 3, "name": "Rahul", "friends": [1], "liked_pages": [101, 103]},
#         {"id": 4, "name": "Sara", "friends": [2], "liked_pages": [104]}
#     ],
#     "pages": [
#         {"id": 101, "name": "Python Developers"},
#         {"id": 102, "name": "Data Science Enthusiasts"},
#         {"id": 103, "name": "AI & ML Community"},
#         {"id": 104, "name": "Web Dev Hub"}
#     ]
# }

# %%
# creation of the file using write mode
r = open("crazy.txt",'w')

r.write("this is Draavith and i am learning python")
# Out:
# 41

# %%
# append mode
a = open("crazy.txt",'a')
a.write("\nthis is Draavith and i am learning python from yt again")
# Out:
# 56
